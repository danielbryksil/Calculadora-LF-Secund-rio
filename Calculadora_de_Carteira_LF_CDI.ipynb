# %% [markdown]
# <a href="https://colab.research.google.com/github/danielbryksil/Calculadora-LF-Secund-rio/blob/main/Calculadora_de_Carteira_LF_CDI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## PU % CDI

# %%
# !pip install python-bcb
# !pip install pandas_market_calendars
# Out:
# Collecting python-bcb
#   Downloading python_bcb-0.2.0-py3-none-any.whl (16 kB)
# Collecting httpx<0.25.0,>=0.24.0 (from python-bcb)
#   Downloading httpx-0.24.1-py3-none-any.whl (75 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 2.5 MB/s eta 0:00:00
# Requirement already satisfied: lxml<5.0.0,>=4.9.2 in /usr/local/lib/python3.10/dist-packages (from python-bcb) (4.9.4)
# Collecting pandas<3.0.0,>=2.0.0 (from python-bcb)
#   Downloading pandas-2.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.0/13.0 MB 23.5 MB/s eta 0:00:00
# Requirement already satisfied: requests<3.0.0,>=2.31.0 in /usr/local/lib/python3.10/dist-packages (from python-bcb) (2.31.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from httpx<0.25.0,>=0.24.0->python-bcb) (2024.2.2)
# Collecting httpcore<0.18.0,>=0.15.0 (from httpx<0.25.0,>=0.24.0->python-bcb)
#   Downloading httpcore-0.17.3-py3-none-any.whl (74 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 74.5/74.5 kB 11.5 MB/s eta 0:00:00
# Requirement already satisfied: idna in /usr/local/lib/python3.10/dist-packages (from httpx<0.25.0,>=0.24.0->python-bcb) (3.6)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from httpx<0.25.0,>=0.24.0->python-bcb) (1.3.0)
# Requirement already satisfied: numpy<2,>=1.22.4 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.0.0->python-bcb) (1.25.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.0.0->python-bcb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas<3.0.0,>=2.0.0->python-bcb) (2023.4)
# Collecting tzdata>=2022.7 (from pandas<3.0.0,>=2.0.0->python-bcb)
#   Downloading tzdata-2024.1-py2.py3-none-any.whl (345 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.4/345.4 kB 38.9 MB/s eta 0:00:00
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->python-bcb) (3.3.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests<3.0.0,>=2.31.0->python-bcb) (2.0.7)
# Collecting h11<0.15,>=0.13 (from httpcore<0.18.0,>=0.15.0->httpx<0.25.0,>=0.24.0->python-bcb)
#   Downloading h11-0.14.0-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 9.2 MB/s eta 0:00:00
# Requirement already satisfied: anyio<5.0,>=3.0 in /usr/local/lib/python3.10/dist-packages (from httpcore<0.18.0,>=0.15.0->httpx<0.25.0,>=0.24.0->python-bcb) (3.7.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas<3.0.0,>=2.0.0->python-bcb) (1.16.0)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5.0,>=3.0->httpcore<0.18.0,>=0.15.0->httpx<0.25.0,>=0.24.0->python-bcb) (1.2.0)
# Installing collected packages: tzdata, h11, pandas, httpcore, httpx, python-bcb
#   Attempting uninstall: pandas
#     Found existing installation: pandas 1.5.3
#     Uninstalling pandas-1.5.3:
#       Successfully uninstalled pandas-1.5.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 0.21.0 requires pandas<2.1.4,>=1.5.0, but you have pandas 2.2.1 which is incompatible.
# google-colab 1.0.0 requires pandas==1.5.3, but you have pandas 2.2.1 which is incompatible.
# Successfully installed h11-0.14.0 httpcore-0.17.3 httpx-0.24.1 pandas-2.2.1 python-bcb-0.2.0 tzdata-2024.1
# Collecting pandas_market_calendars
#   Downloading pandas_market_calendars-4.4.0-py3-none-any.whl (106 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.6/106.6 kB 2.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.1 in /usr/local/lib/python3.10/dist-packages (from pandas_market_calendars) (2.2.1)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from pandas_market_calendars) (2023.4)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from pandas_market_calendars) (2.8.2)
# Collecting exchange-calendars>=3.3 (from pandas_market_calendars)
#   Downloading exchange_calendars-4.5.3-py3-none-any.whl (191 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 191.7/191.7 kB 6.4 MB/s eta 0:00:00
# Requirement already satisfied: numpy<2 in /usr/local/lib/python3.10/dist-packages (from exchange-calendars>=3.3->pandas_market_calendars) (1.25.2)
# Collecting pyluach (from exchange-calendars>=3.3->pandas_market_calendars)
#   Downloading pyluach-2.2.0-py3-none-any.whl (25 kB)
# Requirement already satisfied: toolz in /usr/local/lib/python3.10/dist-packages (from exchange-calendars>=3.3->pandas_market_calendars) (0.12.1)
# Requirement already satisfied: tzdata in /usr/local/lib/python3.10/dist-packages (from exchange-calendars>=3.3->pandas_market_calendars) (2024.1)
# Collecting korean-lunar-calendar (from exchange-calendars>=3.3->pandas_market_calendars)
#   Downloading korean_lunar_calendar-0.3.1-py3-none-any.whl (9.0 kB)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil->pandas_market_calendars) (1.16.0)
# Installing collected packages: korean-lunar-calendar, pyluach, exchange-calendars, pandas_market_calendars
# Successfully installed exchange-calendars-4.5.3 korean-lunar-calendar-0.3.1 pandas_market_calendars-4.4.0 pyluach-2.2.0

# %%
from datetime import datetime
import pandas as pd
from bcb import sgs
import numpy as np
from datetime import datetime, timedelta
from google.colab import files
import pandas as pd
import requests

# %%
dados_excel = pd.read_excel('/content/feriados.xlsx')
feriados = dados_excel['2001-01-01'].tolist()

# %%
df = pd.read_excel('/content/lf secun python %cdi.xlsx')
df
# Out:
#     Tipo Aplic. Data Inicial   Data de Vencimento        Emissor  \
# 0            LF   2022-03-24  2024-05-07 00:00:00   PARANÁ BANCO
# 1            LF   2023-03-08  2024-05-07 00:00:00   PARANÁ BANCO
# 2            LF   2023-03-20  2024-05-07 00:00:00   PARANÁ BANCO
# 3           CDB   2023-11-28  2024-05-22 00:00:00        PAGBANK
# 4           CDB   2023-05-29  2024-05-27 00:00:00  GOLDMAN SACHS
# ..          ...          ...                  ...            ...
# 210        LFSN   2023-01-17  2027-08-02 00:00:00       BRADESCO
# 211        LFSN   2023-01-17  2027-08-02 00:00:00       BRADESCO
# 212        LFSN   2023-01-17  2027-08-02 00:00:00       BRADESCO
# 213        LFSN   2023-03-06  2027-08-02 00:00:00       BRADESCO
# 214        LFSN   2023-01-17  2027-08-03 00:00:00       BRADESCO
#
#                  Banco  Valor Inicial  Valor Aplicado  Taxa COMPRA  \
# 0    BANCO BRADESCO SA     1625475.65      2092938.40       1.1150
# 1    BANCO BRADESCO SA     5031809.58      5681114.45       1.1190
# 2    BANCO BRADESCO SA     5054528.28      5680884.93       1.1190
# 3    BANCO BRADESCO SA     3003114.00      3065661.28       1.0840
# 4    BANCO BRADESCO SA    25029110.81     27303601.92       1.0800
# ..                 ...            ...             ...          ...
# 210  BANCO BRADESCO SA      399584.55       460293.63       1.1250
# 211  BANCO BRADESCO SA     1997922.78      2301468.13       1.1250
# 212  BANCO BRADESCO SA      799169.11       920587.25       1.1250
# 213  BANCO BRADESCO SA      406776.17       460065.61       1.1245
# 214  BANCO BRADESCO SA     2396183.45      2760236.73       1.1250
#
#          Transação        Titulo Data Emissão Data Vencimento  PU Inicial  \
# 0    1000000006342   LF0019007Z4   2019-05-07      2024-05-07    200000.0
# 1    1000000007218   LF0019007Z4   2019-05-07      2024-05-07    200000.0
# 2    1000000007260  LF0019007Z4    2019-05-07      2024-05-07    200000.0
# 3    1000000007623  CDBB23A6UNU    2023-11-24      2024-05-22      1000.0
# 4    1000000007468   CDB223JODX8   2023-05-26      2024-05-27      1000.0
# ..             ...           ...          ...             ...         ...
# 210  1000000007069   LFSN1800DF4   2018-08-01      2027-08-02    300000.0
# 211  1000000007071   LFSN1800DF3   2018-08-01      2027-08-02    300000.0
# 212  1000000007072   LFSN1800DG2   2018-08-01      2027-08-02    300000.0
# 213  1000000007213   LFSN1800DEZ   2018-08-01      2027-08-02    300000.0
# 214  1000000007073   LFSN1800DIJ   2018-08-03      2027-08-03    300000.0
#
#      Taxa de Emissão  Taxa de Venda  Quantidade
# 0              1.130           1.06           7
# 1              1.130           1.06          19
# 2              1.130           1.06          19
# 3              1.085           1.08        3000
# 4              1.090           1.05       25000
# ..               ...            ...         ...
# 210            1.095           1.10           1
# 211            1.095           1.10           5
# 212            1.095           1.10           2
# 213            1.095           1.10           1
# 214            1.095           1.10           6
#
# [215 rows x 16 columns]

# %%
data_operação = input("Qual a data da operação (aaaa-mm-dd)? ")
# Out:
# Qual a data da operação (aaaa-mm-dd)? 2024-02-27

# %%
data_str = data_operação
data = datetime.strptime(data_str, '%Y-%m-%d')
data_menos_um_dia = data - timedelta(days=1)

# Converta o resultado de volta para o formato desejado
data_menos_um_dia_operação = data_menos_um_dia.strftime('%Y-%m-%d')
data_menos_um_dia_operação
# Out:
# '2024-02-26'

# %%
data1 = pd.to_datetime(df['Data Vencimento'])
data2 = pd.to_datetime(data_operação)
df['dias_venc'] = (data1 - data2)
df['dias_venc'] = (df['dias_venc'].dt.days)-1
df
# Out:
#     Tipo Aplic. Data Inicial   Data de Vencimento        Emissor  \
# 0            LF   2022-03-24  2024-05-07 00:00:00   PARANÁ BANCO
# 1            LF   2023-03-08  2024-05-07 00:00:00   PARANÁ BANCO
# 2            LF   2023-03-20  2024-05-07 00:00:00   PARANÁ BANCO
# 3           CDB   2023-11-28  2024-05-22 00:00:00        PAGBANK
# 4           CDB   2023-05-29  2024-05-27 00:00:00  GOLDMAN SACHS
# ..          ...          ...                  ...            ...
# 210        LFSN   2023-01-17  2027-08-02 00:00:00       BRADESCO
# 211        LFSN   2023-01-17  2027-08-02 00:00:00       BRADESCO
# 212        LFSN   2023-01-17  2027-08-02 00:00:00       BRADESCO
# 213        LFSN   2023-03-06  2027-08-02 00:00:00       BRADESCO
# 214        LFSN   2023-01-17  2027-08-03 00:00:00       BRADESCO
#
#                  Banco  Valor Inicial  Valor Aplicado  Taxa COMPRA  \
# 0    BANCO BRADESCO SA     1625475.65      2092938.40       1.1150
# 1    BANCO BRADESCO SA     5031809.58      5681114.45       1.1190
# 2    BANCO BRADESCO SA     5054528.28      5680884.93       1.1190
# 3    BANCO BRADESCO SA     3003114.00      3065661.28       1.0840
# 4    BANCO BRADESCO SA    25029110.81     27303601.92       1.0800
# ..                 ...            ...             ...          ...
# 210  BANCO BRADESCO SA      399584.55       460293.63       1.1250
# 211  BANCO BRADESCO SA     1997922.78      2301468.13       1.1250
# 212  BANCO BRADESCO SA      799169.11       920587.25       1.1250
# 213  BANCO BRADESCO SA      406776.17       460065.61       1.1245
# 214  BANCO BRADESCO SA     2396183.45      2760236.73       1.1250
#
#          Transação        Titulo Data Emissão Data Vencimento  PU Inicial  \
# 0    1000000006342   LF0019007Z4   2019-05-07      2024-05-07    200000.0
# 1    1000000007218   LF0019007Z4   2019-05-07      2024-05-07    200000.0
# 2    1000000007260  LF0019007Z4    2019-05-07      2024-05-07    200000.0
# 3    1000000007623  CDBB23A6UNU    2023-11-24      2024-05-22      1000.0
# 4    1000000007468   CDB223JODX8   2023-05-26      2024-05-27      1000.0
# ..             ...           ...          ...             ...         ...
# 210  1000000007069   LFSN1800DF4   2018-08-01      2027-08-02    300000.0
# 211  1000000007071   LFSN1800DF3   2018-08-01      2027-08-02    300000.0
# 212  1000000007072   LFSN1800DG2   2018-08-01      2027-08-02    300000.0
# 213  1000000007213   LFSN1800DEZ   2018-08-01      2027-08-02    300000.0
# 214  1000000007073   LFSN1800DIJ   2018-08-03      2027-08-03    300000.0
#
#      Taxa de Emissão  Taxa de Venda  Quantidade  dias_venc
# 0              1.130           1.06           7         69
# 1              1.130           1.06          19         69
# 2              1.130           1.06          19         69
# 3              1.085           1.08        3000         84
# 4              1.090           1.05       25000         89
# ..               ...            ...         ...        ...
# 210            1.095           1.10           1       1251
# 211            1.095           1.10           5       1251
# 212            1.095           1.10           2       1251
# 213            1.095           1.10           1       1251
# 214            1.095           1.10           6       1252
#
# [215 rows x 17 columns]

# %%
data_cdi = sgs.get(('CDI', 12), last=3000)
data_cdi = data_cdi['CDI']
data_cdi
# Out:
# Date
# 2012-03-15    0.035839
# 2012-03-16    0.035984
# 2012-03-19    0.035948
# 2012-03-20    0.035948
# 2012-03-21    0.035948
#                 ...
# 2024-02-21    0.041957
# 2024-02-22    0.041957
# 2024-02-23    0.041957
# 2024-02-26    0.041957
# 2024-02-27    0.041957
# Name: CDI, Length: 3000, dtype: float64

# %%
data_cdi
# Out:
# Date
# 2012-03-15    0.035839
# 2012-03-16    0.035984
# 2012-03-19    0.035948
# 2012-03-20    0.035948
# 2012-03-21    0.035948
#                 ...
# 2024-02-21    0.041957
# 2024-02-22    0.041957
# 2024-02-23    0.041957
# 2024-02-26    0.041957
# 2024-02-27    0.041957
# Name: CDI, Length: 3000, dtype: float64

# %%
di_per_list = []

for a, b in zip(df['Data Emissão'], df['Taxa de Emissão']):
    data_filt = data_cdi.loc[a:data_menos_um_dia_operação]
    di = (data_filt/100 * b)+1
    di_per = di.product()
    di_per_list.append(di_per)

df['di_acum'] = di_per_list

# %%
# URL da página
url = 'https://www2.bmf.com.br/pages/portal/bmfbovespa/boletim1/TxRef1.asp'

# Realiza a solicitação HTTP
response = requests.get(url)

# Verifica se a solicitação foi bem-sucedida (código de status 200)
if response.status_code == 200:
    # Lê a tabela HTML diretamente usando o pandas
    dfs = pd.read_html(response.text, flavor='bs4')  # 'bs4' indica o uso do BeautifulSoup para análise HTML

    # O resultado será uma lista de DataFrames, onde cada DataFrame representa uma tabela na página
    # Dependendo da página, você pode precisar procurar qual DataFrame contém os dados desejados
    for i, b in enumerate(dfs):
        print(f"DataFrame {i + 1}:\n{b}")
else:
    print(f"Falha na solicitação. Código de status: {response.status_code}")

di_tabela = dfs[2]
di_tabela = di_tabela.set_index(0)
di_tabela = di_tabela.iloc[2:]
di_tabela = di_tabela[1]
di_tabela = di_tabela.astype(float)
di_tabela.index = di_tabela.index.astype(int)
di_tabela = di_tabela/100
# Out:
# <ipython-input-11-c1f5a03fc16b>:10: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(response.text, flavor='bs4')  # 'bs4' indica o uso do BeautifulSoup para análise HTML
# DataFrame 1:
#                                                    0            1
# 0                          Atualizado em: 27/02/2024  Retroativo:
# 1  Taxa: Ajuste cupom  Alumínio  DI x Anbid  Anbi...          NaN
# DataFrame 2:
#                                                      0          1         2
# 0    Dias Corridos DI x pré 252(2)(4) 360(1) 1 11,1...        NaN       NaN
# 1                                        Dias Corridos   DI x pré  DI x pré
# 2                                        Dias Corridos  252(2)(4)    360(1)
# 3                                                    1       1115       000
# 4                                                    2       1115      1631
# ..                                                 ...        ...       ...
# 258                                               9485       1089      1066
# 259                                               9666       1089      1066
# 260                                              10800       1089      1066
# 261                                              11402       1089      1066
# 262                                              13320       1089      1066
#
# [263 rows x 3 columns]
# DataFrame 3:
#                  0          1         2
# 0    Dias Corridos   DI x pré  DI x pré
# 1    Dias Corridos  252(2)(4)    360(1)
# 2                1       1115       000
# 3                2       1115      1631
# 4                3       1116      1631
# ..             ...        ...       ...
# 257           9485       1089      1066
# 258           9666       1089      1066
# 259          10800       1089      1066
# 260          11402       1089      1066
# 261          13320       1089      1066
#
# [262 rows x 3 columns]
# DataFrame 4:
#                                                    0
# 0  (1) Taxa efetiva para 360 dias corridos. (2) T...

# %%
df_di_tabela = pd.DataFrame(di_tabela)
df_di_tabela
# Out:
#            1
# 0
# 1      11.15
# 2      11.15
# 3      11.16
# 7      11.10
# 10     11.06
# ...      ...
# 9485   10.89
# 9666   10.89
# 10800  10.89
# 11402  10.89
# 13320  10.89
#
# [260 rows x 1 columns]

# %%
def interpolar_valor(df, x):
  # Encontrar a linha na tabela onde o valor X está presente ou próximo.
  linha = df.index[df.index <= x].max()

  # Se o valor X já estiver presente na tabela DI, retornar o valor correspondente.
  if linha == x:
    return round(df.loc[linha,1],2)

  # Se o valor X não estiver presente na tabela DI, interpolar.
  if linha != x:
    di_anterior = df_di_tabela.loc[linha,1]
    posicao = df_di_tabela.index.get_loc(linha)
    # Obter o próximo índice
    proximo_indice = posicao + 1
    di_prox = df_di_tabela[1].iloc[proximo_indice]
    prox_num_dias_di = df_di_tabela.index[proximo_indice]
    interpolação = di_anterior + (x-linha) * ((di_prox-di_anterior) / (prox_num_dias_di-linha))
    return round(interpolação,2)

  return 0

# %%
di_dia_list = []

for a in df['dias_venc']:
  tx_di = interpolar_valor(df_di_tabela, a) /100
  di_dia_list.append(tx_di)

df['di_dia'] = di_dia_list
df['pu_par'] = df['PU Inicial'] * df['di_acum']

# %%
num_dias_uteis = []

for a in df['Data Emissão']:
    datas = pd.date_range(start=a, end=data_operação, freq='B')
    dias_uteis = datas[~datas.isin(feriados)]
    dias_uteis_b = len(dias_uteis)-1
    num_dias_uteis.append(dias_uteis_b)


df['num_dias_uteis'] = num_dias_uteis
num_dias_uteis_oper_venc = []

for a in df['Data Vencimento']:
    datas = pd.date_range(start=data_operação, end=a, freq='B')
    dias_uteis = datas[~datas.isin(feriados)]
    dias_uteis_b = len(dias_uteis)-1
    num_dias_uteis_oper_venc.append(dias_uteis_b)


df['num_dias_uteis_oper'] = num_dias_uteis_oper_venc

# %%
df['di_int_acum'] =((((1+df['di_dia'])**(1/252)-1)*df['Taxa de Emissão'])+1)**(252)-1
df['di_int_acum_2'] = +(1+df['di_int_acum'])**(df['num_dias_uteis_oper']/252)-1
df['neg_di_acum']=((((1+ df['di_dia'])**(1/252)-1)*  df['Taxa de Venda'] )+1)**(252)-1
df['neg_di_acum_2'] =+(1+df['neg_di_acum'])**(df['num_dias_uteis_oper']/252)-1
df['vf'] = (df['di_int_acum_2']+1) * df['pu_par']
df['pu_final'] = df['vf'] / (1+ df['neg_di_acum_2'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 28 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Tipo Aplic.          215 non-null    object
#  1   Data Inicial         215 non-null    datetime64[ns]
#  2   Data de Vencimento   215 non-null    object
#  3   Emissor              215 non-null    object
#  4   Banco                215 non-null    object
#  5   Valor Inicial        215 non-null    float64
#  6   Valor Aplicado       215 non-null    float64
#  7   Taxa COMPRA          215 non-null    float64
#  8   Transação            215 non-null    int64
#  9   Titulo               202 non-null    object
#  10  Data Emissão         215 non-null    datetime64[ns]
#  11  Data Vencimento      215 non-null    datetime64[ns]
#  12  PU Inicial           215 non-null    float64
#  13  Taxa de Emissão      215 non-null    float64
#  14  Taxa de Venda        215 non-null    float64
#  15  Quantidade           215 non-null    int64
#  16  dias_venc            215 non-null    int64
#  17  di_acum              215 non-null    float64
#  18  di_dia               215 non-null    float64
#  19  pu_par               215 non-null    float64
#  20  num_dias_uteis       215 non-null    int64
#  21  num_dias_uteis_oper  215 non-null    int64
#  22  di_int_acum          215 non-null    float64
#  23  di_int_acum_2        215 non-null    float64
#  24  neg_di_acum          215 non-null    float64
#  25  neg_di_acum_2        215 non-null    float64
#  26  vf                   215 non-null    float64
#  27  pu_final             215 non-null    float64
# dtypes: datetime64[ns](3), float64(15), int64(5), object(5)
# memory usage: 47.2+ KB

# %%
df_filtro = df[['Tipo Aplic.', 'Data Inicial', 'Emissor', 'Banco',
       'Valor Inicial', 'Taxa COMPRA', 'Transação', 'Titulo',
       'Data Emissão', 'Data Vencimento', 'PU Inicial', 'Taxa de Emissão', 'Taxa de Venda','pu_final','Quantidade']]

# %%
df_filtro
# Out:
#     Tipo Aplic. Data Inicial        Emissor              Banco  Valor Inicial  \
# 0            LF   2022-03-24   PARANÁ BANCO  BANCO BRADESCO SA     1625475.65
# 1            LF   2023-03-08   PARANÁ BANCO  BANCO BRADESCO SA     5031809.58
# 2            LF   2023-03-20   PARANÁ BANCO  BANCO BRADESCO SA     5054528.28
# 3           CDB   2023-11-28        PAGBANK  BANCO BRADESCO SA     3003114.00
# 4           CDB   2023-05-29  GOLDMAN SACHS  BANCO BRADESCO SA    25029110.81
# ..          ...          ...            ...                ...            ...
# 210        LFSN   2023-01-17       BRADESCO  BANCO BRADESCO SA      399584.55
# 211        LFSN   2023-01-17       BRADESCO  BANCO BRADESCO SA     1997922.78
# 212        LFSN   2023-01-17       BRADESCO  BANCO BRADESCO SA      799169.11
# 213        LFSN   2023-03-06       BRADESCO  BANCO BRADESCO SA      406776.17
# 214        LFSN   2023-01-17       BRADESCO  BANCO BRADESCO SA     2396183.45
#
#      Taxa COMPRA      Transação        Titulo Data Emissão Data Vencimento  \
# 0         1.1150  1000000006342   LF0019007Z4   2019-05-07      2024-05-07
# 1         1.1190  1000000007218   LF0019007Z4   2019-05-07      2024-05-07
# 2         1.1190  1000000007260  LF0019007Z4    2019-05-07      2024-05-07
# 3         1.0840  1000000007623  CDBB23A6UNU    2023-11-24      2024-05-22
# 4         1.0800  1000000007468   CDB223JODX8   2023-05-26      2024-05-27
# ..           ...            ...           ...          ...             ...
# 210       1.1250  1000000007069   LFSN1800DF4   2018-08-01      2027-08-02
# 211       1.1250  1000000007071   LFSN1800DF3   2018-08-01      2027-08-02
# 212       1.1250  1000000007072   LFSN1800DG2   2018-08-01      2027-08-02
# 213       1.1245  1000000007213   LFSN1800DEZ   2018-08-01      2027-08-02
# 214       1.1250  1000000007073   LFSN1800DIJ   2018-08-03      2027-08-03
#
#      PU Inicial  Taxa de Emissão  Taxa de Venda       pu_final  Quantidade
# 0      200000.0            1.130           1.06  301888.201096           7
# 1      200000.0            1.130           1.06  301888.201096          19
# 2      200000.0            1.130           1.06  301888.201096          19
# 3        1000.0            1.085           1.08    1030.423743        3000
# 4        1000.0            1.090           1.05    1102.528656       25000
# ..          ...              ...            ...            ...         ...
# 210    300000.0            1.095           1.10  469053.678371           1
# 211    300000.0            1.095           1.10  469053.678371           5
# 212    300000.0            1.095           1.10  469053.678371           2
# 213    300000.0            1.095           1.10  469053.678371           1
# 214    300000.0            1.095           1.10  468800.355409           6
#
# [215 rows x 15 columns]

# %%
carteira = pd.read_excel('/content/Carteira.xlsm')
carteira
# Out:
#      Empresa Tipo Aplic. Data Inicial Data Posicao Data de Carência  \
# 0     1000.0         CDB   2022-06-21   2024-02-27       21/07/2022
# 1     1000.0         CDB   2022-06-23   2024-02-27       23/07/2022
# 2     1000.0         CDB   2022-06-27   2024-02-27       27/07/2022
# 3     1000.0         CDB   2022-07-04   2024-02-27       03/08/2022
# 4     1000.0         CDB   2022-07-07   2024-02-27       06/08/2022
# ..       ...         ...          ...          ...              ...
# 338   1000.0         TL2   2024-02-20   2024-02-27       21/11/2024
# 339   1000.0         TL2   2024-02-22   2024-02-27       17/02/2025
# 340   1000.0         TL2   2024-02-23   2024-02-27       16/12/2024
# 341   1000.0         TL2   2024-02-23   2024-02-27       17/02/2025
# 342      NaN         NaN          NaT          NaT              NaN
#
#     Data de Vencimento                         Fundo Emissor        Nº ID  \
# 0           2027-06-21    Cert. de Depósito Bancário     NaN          NaN
# 1           2027-06-23    Cert. de Depósito Bancário     NaN          NaN
# 2           2027-06-25    Cert. de Depósito Bancário     NaN          NaN
# 3           2027-07-06    Cert. de Depósito Bancário     NaN          NaN
# 4           2027-07-07    Cert. de Depósito Bancário     NaN          NaN
# ..                 ...                           ...     ...          ...
# 338         2024-11-21  Letra de Financeira indexada    ITAU   200224_TL2
# 339         2025-02-17  Letra de Financeira indexada    ITAU   220224_TL2
# 340         2024-12-16  Letra de Financeira indexada    ITAU  230224_TL22
# 341         2025-02-17  Letra de Financeira indexada    ITAU   230224_TL2
# 342                NaT                           NaN     NaN          NaN
#
#         Transação                         Banco  Valor Aplicado
# 0    1.000000e+12  BANCO COOPERATIVO SICREDI SA    7.408519e+06
# 1    1.000000e+12  BANCO COOPERATIVO SICREDI SA    4.419636e+06
# 2    1.000000e+12  BANCO COOPERATIVO SICREDI SA    9.220972e+05
# 3    1.000000e+12  BANCO COOPERATIVO SICREDI SA    1.903919e+07
# 4    1.000000e+12  BANCO COOPERATIVO SICREDI SA    8.966061e+06
# ..            ...                           ...             ...
# 338  1.000000e+12              ITAU UNIBANCO SA    5.174530e+06
# 339  1.000000e+12              ITAU UNIBANCO SA    1.011946e+07
# 340  1.000000e+12              ITAU UNIBANCO SA    5.733195e+06
# 341  1.000000e+12              ITAU UNIBANCO SA    8.804506e+06
# 342           NaN                           NaN    2.617863e+09
#
# [343 rows x 12 columns]

# %%
resultado = pd.merge(df_filtro, carteira[['Transação','Valor Aplicado']], on='Transação', how='left')
resultado['Valor Mercado'] = resultado['pu_final'] * resultado['Quantidade']
resultado['Ganho/Perda'] = resultado['Valor Mercado'] - resultado['Valor Aplicado']
resultado['Ganho/Perda %'] = resultado['Ganho/Perda'] / resultado['Valor Aplicado']
resultado
# Out:
#     Tipo Aplic. Data Inicial        Emissor              Banco  Valor Inicial  \
# 0            LF   2022-03-24   PARANÁ BANCO  BANCO BRADESCO SA     1625475.65
# 1            LF   2023-03-08   PARANÁ BANCO  BANCO BRADESCO SA     5031809.58
# 2            LF   2023-03-20   PARANÁ BANCO  BANCO BRADESCO SA     5054528.28
# 3           CDB   2023-11-28        PAGBANK  BANCO BRADESCO SA     3003114.00
# 4           CDB   2023-05-29  GOLDMAN SACHS  BANCO BRADESCO SA    25029110.81
# ..          ...          ...            ...                ...            ...
# 210        LFSN   2023-01-17       BRADESCO  BANCO BRADESCO SA      399584.55
# 211        LFSN   2023-01-17       BRADESCO  BANCO BRADESCO SA     1997922.78
# 212        LFSN   2023-01-17       BRADESCO  BANCO BRADESCO SA      799169.11
# 213        LFSN   2023-03-06       BRADESCO  BANCO BRADESCO SA      406776.17
# 214        LFSN   2023-01-17       BRADESCO  BANCO BRADESCO SA     2396183.45
#
#      Taxa COMPRA      Transação        Titulo Data Emissão Data Vencimento  \
# 0         1.1150  1000000006342   LF0019007Z4   2019-05-07      2024-05-07
# 1         1.1190  1000000007218   LF0019007Z4   2019-05-07      2024-05-07
# 2         1.1190  1000000007260  LF0019007Z4    2019-05-07      2024-05-07
# 3         1.0840  1000000007623  CDBB23A6UNU    2023-11-24      2024-05-22
# 4         1.0800  1000000007468   CDB223JODX8   2023-05-26      2024-05-27
# ..           ...            ...           ...          ...             ...
# 210       1.1250  1000000007069   LFSN1800DF4   2018-08-01      2027-08-02
# 211       1.1250  1000000007071   LFSN1800DF3   2018-08-01      2027-08-02
# 212       1.1250  1000000007072   LFSN1800DG2   2018-08-01      2027-08-02
# 213       1.1245  1000000007213   LFSN1800DEZ   2018-08-01      2027-08-02
# 214       1.1250  1000000007073   LFSN1800DIJ   2018-08-03      2027-08-03
#
#      PU Inicial  Taxa de Emissão  Taxa de Venda       pu_final  Quantidade  \
# 0      200000.0            1.130           1.06  301888.201096           7
# 1      200000.0            1.130           1.06  301888.201096          19
# 2      200000.0            1.130           1.06  301888.201096          19
# 3        1000.0            1.085           1.08    1030.423743        3000
# 4        1000.0            1.090           1.05    1102.528656       25000
# ..          ...              ...            ...            ...         ...
# 210    300000.0            1.095           1.10  469053.678371           1
# 211    300000.0            1.095           1.10  469053.678371           5
# 212    300000.0            1.095           1.10  469053.678371           2
# 213    300000.0            1.095           1.10  469053.678371           1
# 214    300000.0            1.095           1.10  468800.355409           6
#
#      Valor Aplicado  Valor Mercado   Ganho/Perda  Ganho/Perda %
# 0        2110716.80   2.113217e+06   2500.607674       0.001185
# 1        5729546.33   5.735876e+06   6329.490829       0.001105
# 2        5729314.85   5.735876e+06   6560.970829       0.001145
# 3        3090975.62   3.091271e+06    295.608897       0.000096
# 4       27528223.06   2.756322e+07  34993.351500       0.001271
# ..              ...            ...           ...            ...
# 210       464238.79   4.690537e+05   4814.888371       0.010372
# 211      2321193.93   2.345268e+06  24074.461856       0.010372
# 212       928477.57   9.381074e+05   9629.786742       0.010372
# 213       464007.05   4.690537e+05   5046.628371       0.010876
# 214      2783894.62   2.812802e+06  28907.512453       0.010384
#
# [215 rows x 19 columns]

# %%
nome_arquivo_excel2 = 'LF %CDI.xlsx'
resultado.to_excel(nome_arquivo_excel2, index=False)

# %%
# Fazer o download do arquivo Excel
files.download(nome_arquivo_excel2)
